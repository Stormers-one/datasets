# %%
import re
import pandas as pd
import numpy as np

import geopandas as gp
import plotly.graph_objects as go

import requests
from urllib.request import urlopen
import json

import plotly.express as px

# %%
data_files = [
    'trips.txt',
    'stops.txt',
    'stop_times.txt',
    'routes.txt',
    'calendar.txt',
    'agency.txt'
]
data_loc = {}
pattern = r'([\w_]+).txt'

for x in data_files:
    y = re.findall(pattern, x)[0]
    data_loc[y] = '../Dataset GTFS/GTFS/'+x

# %%
data_loc
# Out:
# {'trips': '../Dataset GTFS/GTFS/trips.txt',
#  'stops': '../Dataset GTFS/GTFS/stops.txt',
#  'stop_times': '../Dataset GTFS/GTFS/stop_times.txt',
#  'routes': '../Dataset GTFS/GTFS/routes.txt',
#  'calendar': '../Dataset GTFS/GTFS/calendar.txt',
#  'agency': '../Dataset GTFS/GTFS/agency.txt'}

# %%
data = {}
for key,value in data_loc.items():
    data[key] = pd.read_csv("{}".format(value), sep = ',')

# %%
for key, value in data.items():
    print("{}\n{}\n".format(key,value.head()))
# Out:
# trips
#    route_id  service_id trip_id  shape_id
# 0         0           1   0_6_0       0.0
# 1         0           1  0_6_10       0.0
# 2         0           1  0_6_20       0.0
# 3         0           1  0_6_30       0.0
# 4         0           1  0_6_40       0.0
#
# stops
#    stop_id                       stop_name   stop_lat   stop_lon
# 0        0  Adarsh Nagar / Bharola Village  28.715917  77.170867
# 1        1          British High Comission  28.598533  77.191383
# 2        2                     Azad Market  28.664700  77.208400
# 3        3                    Kidwai Nagar  28.575700  77.209700
# 4        4                   Rashid Market  28.650200  77.278667
#
# stop_times
#   trip_id arrival_time departure_time  stop_id  stop_sequence
# 0   0_6_0     06:00:00       06:00:00     2101              0
# 1   0_6_0     06:01:52       06:01:52      909              1
# 2   0_6_0     06:04:17       06:04:17     2790              2
# 3   0_6_0     06:06:02       06:06:02      236              3
# 4   0_6_0     06:08:47       06:08:47     2855              4
#
# routes
#    route_short_name route_long_name  route_type  route_id agency_id
# 0               NaN         108DOWN           3         0     DIMTS
# 1               NaN      108STLDOWN           3         1     DIMTS
# 2               NaN        108STLUP           3         2     DIMTS
# 3               NaN           108UP           3         3     DIMTS
# 4               NaN         185DOWN           3         4     DIMTS
#
# calendar
#    start_date  end_date  monday  tuesday  wednesday  thursday  friday  \
# 0    20191001  20201001       1        1          1         1       1
#
#    saturday  sunday  service_id
# 0         1       1           1
#
# agency
#   agency_id                                       agency_name  \
# 0     DIMTS  Delhi Integrated Multi-Modal Transit System Ltd.
# 1       DTC                       Delhi Transport Corporation
#
#                 agency_url agency_timezone agency_lang  agency_phone  \
# 0    https://www.dimts.in/    Asia/Kolkata          en    1143090100
# 1  http://dtc.nic.in/home/    Asia/Kolkata          en    1123370373
#
#    agency_fare_url
# 0              NaN
# 1              NaN

# %%
map_url = "https://raw.githubusercontent.com/Stormers-one/datasets/master/Analyis/maps/map.geojson"
with urlopen(map_url) as response:
    map_india = json.load(response)

# %%
px.choropleth(
    geojson = map_india, 
    locations= 'properties. ',
    featureidkey = 'properties.NAME_2'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5c175e9755b8> in <module>
# ----> 1 px.choropleth(
#       2     geojson = map_india,
#       3     locations= 'properties ',
#       4     featureidkey = 'properties.NAME_2'
#       5 )
#
# ~\.conda\envs\PyML32\lib\site-packages\plotly\express\_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#     972     colored region mark on a map.
#     973     """
# --> 974     return make_figure(
#     975         args=locals(),
#     976         constructor=go.Choropleth,
#
# ~\.conda\envs\PyML32\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1831     apply_default_cascade(args)
#    1832
# -> 1833     args = build_dataframe(args, constructor)
#    1834     if constructor in [go.Treemap, go.Sunburst] and args["path"] is not None:
#    1835         args = process_dataframe_hierarchy(args)
#
# ~\.conda\envs\PyML32\lib\site-packages\plotly\express\_core.py in build_dataframe(args, constructor)
#    1355     # now that things have been prepped, we do the systematic rewriting of `args`
#    1356
# -> 1357     df_output, wide_id_vars = process_args_into_dataframe(
#    1358         args, wide_mode, var_name, value_name
#    1359     )
#
# ~\.conda\envs\PyML32\lib\site-packages\plotly\express\_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1143                     df_output[col_name] = to_unindexed_series(real_argument)
#    1144                 elif not df_provided:
# -> 1145                     raise ValueError(
#    1146                         "String or int arguments are only possible when a "
#    1147                         "DataFrame or an array is provided in the `data_frame` "
#
# ValueError: String or int arguments are only possible when a DataFrame or an array is provided in the `data_frame` argument. No DataFrame was provided, but argument 'locations' is of type str or int.

# %%
map_data = gp.read_file("maps/map.geojson")

# %%
map_data.head()
# Out:
#    ISO NAME_0  ID_1             NAME_1   ID_2               NAME_2  \
# 0  IND  India  1289  Arunachal Pradesh  15745           Papum Pare
# 1  IND  India  1289  Arunachal Pradesh  15746               Tawang
# 2  IND  India  1289  Arunachal Pradesh  15747                Tirap
# 3  IND  India  1289  Arunachal Pradesh  15748  Upper Dibang Valley
# 4  IND  India  1289  Arunachal Pradesh  15749          Upper Siang
#
#               VARNAME_2    HASC_2    TYPE_2 ENGTYPE_2  \
# 0                        IN.AR.PA  District  District
# 1                        IN.AR.TA  District  District
# 2  Tirap Frontier Tract  IN.AR.TI  District  District
# 3                                  District  District
# 4                        IN.AR.US  District  District
#
#                                             geometry
# 0  POLYGON ((94.21063 27.49826, 94.08677 27.40479...
# 1  POLYGON ((92.31558 27.77868, 92.27933 27.67687...
# 2  POLYGON ((95.63745 27.23728, 95.65557 27.13362...
# 3  POLYGON ((96.36747 28.56347, 96.15199 28.65509...
# 4  POLYGON ((95.27193 29.05860, 95.24273 29.00214...

# %%
df = data['stops']
df.head()
# Out:
#    stop_id                       stop_name   stop_lat   stop_lon
# 0        0  Adarsh Nagar / Bharola Village  28.715917  77.170867
# 1        1          British High Comission  28.598533  77.191383
# 2        2                     Azad Market  28.664700  77.208400
# 3        3                    Kidwai Nagar  28.575700  77.209700
# 4        4                   Rashid Market  28.650200  77.278667

# %%
fig = go.Figure(data=go.Scattergeo(
        lon = df['stop_lon'],
        lat = df['stop_lat'],
        text = df['stop_name'],
        mode = 'markers',
        ))

fig.update_layout(
        title = 'Stops in delhi',
        geo_scope='asia',
    )
fig.show()
# Out:
# <div>                            <div id="75de687e-20c3-4ba9-a023-39718c51815a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75de687e-20c3-4ba9-a023-39718c51815a")) {                    Plotly.newPlot(                        "75de687e-20c3-4ba9-a023-39718c51815a",                        [{"lat": [28.715916999999997, 28.598533000000003, 28.6647, 28.5757, 28.6502, 28.56915, 28.602217, 28.661283, 28.6147, 28.64608333, 28.68755, 28.801917, 28.608213, 28.6115, 28.61335, 28.562316999999997, 28.7315, 28.58931667, 28.640024, 28.6803, 28.687016999999997, 28.553099, 28.502066999999997, 28.6018, 28.657906, 28.613000000000003, 28.685237, 28.853365000000004, 28.69905, 28.7316, 28.641920000000002, 28.71645, 